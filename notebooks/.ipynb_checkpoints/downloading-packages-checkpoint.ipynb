# %%
import os
import glob
import magic
from pathlib import Path
import shutil
import subprocess
import tarfile
import zipfile

# %%
# Extracting all artifacts
def uncompressing_artifact(package_name, artifact_file, dst_dir):
    extracted_dir = os.path.join(dst_dir, package_name)
  
    if not os.path.exists(extracted_dir):
        os.mkdir(extracted_dir)       
        if str(artifact_file).endswith(".tar.gz"):
            tfile = tarfile.open(artifact_file)
            tfile.extractall(extracted_dir)
            tfile.close()
        elif str(artifact_file).endswith((".whl", ".zip", ".egg")) :
            with zipfile.ZipFile(artifact_file, 'r') as zip_ref:
                zip_ref.extractall(extracted_dir)

# %%
oss_download_path = os.path.abspath("../scanners/OSSGadget/src/oss-download/bin/Debug/net6.0/oss-download")

# %%
popular_packages_list_path = os.path.abspath("../dataset/metadata/popular-packages.txt")
popular_packages_dir = os.path.abspath("../dataset/popular-packages")

# %%
def download_packages(packages_list_path, packages_dir):
    with open(packages_list_path) as file:
        while (package := file.readline().rstrip()):
            p = subprocess.run([oss_download_path, "--download-metadata-only", f"pkg:pypi/{package}"], capture_output=True, text=True)
            version_lst = p.stderr.split("@")[-1].split("-")
            # Extracting version of a package
            version = ""

            if version_lst:
                try:
                    version = version_lst[:-1][0]
                except IndexError:
                    # in some cases, packages names do not appear in right formats, but that's not so important
                    version = version_lst[0].replace(".tar.gz", "")
            else:
                version = version_lst[0]
            print(package, version)
            dst_dir = Path(packages_dir, package, version)

            # Fresh new downloads here to avoid confusions
            if dst_dir.exists():
                continue
                #shutil.rmtree(dst_dir)
            dst_dir.mkdir(parents=True, exist_ok=True)

            subprocess.run([oss_download_path, "--download-directory", dst_dir, f"pkg:pypi/{package}"])

            artifacts = glob.glob(f"{dst_dir}/*")

            # Prioritize source tarballs over distibutions as they have setup.py files
            for artifact in artifacts:
                artifact_type = magic.from_file(artifact).lower()
                if artifact.endswith(".tar.gz") and artifact_type.startswith("gzip"):
                    tfile = tarfile.open(artifact)
                    tfile.extractall(dst_dir)
                    tfile.close()
                    os.remove(artifact)
                    break
                # In some cases, oss-download misrecognize zip files as tar files
                elif (artifact.endswith(".tar.gz") and artifact_type.startswith("zip")) or (artifact.endswith(".zip") and artifact_type.startswith("zip")):
                    with zipfile.ZipFile(artifact, 'r') as zip_ref:
                        zip_ref.extractall(dst_dir)
                        zip_ref.close()
                        os.remove(artifact)
                        break
            else:
                if artifact_type.startswith(("zip")):
                    with zipfile.ZipFile(artifact, 'r') as zip_ref:
                        zip_ref.extractall(dst_dir)
                        zip_ref.close()
                        os.remove(artifact)

            # Clean up the downloaded directory to only keep the uncompressed directory
            for item in os.listdir(dst_dir):
                left_over_file = os.path.join(dst_dir, item)
                if os.path.isfile(left_over_file):
                    os.remove(left_over_file)

# %%
random_packages_list_path = os.path.abspath("../dataset/metadata/random-packages.txt")
random_packages_dir = os.path.abspath("../dataset/random-packages/")

# %%
download_packages(random_packages_list_path, random_packages_dir)
# Out:
# expose-localhost 0.4.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/expose-localhost to /home/lyvd/bad-snakes/dataset/random-packages/expose-localhost/0.4.2/pypi-bdist_wheel-expose-localhost@0.4.2.whl
# INFO  - Downloaded pkg:pypi/expose-localhost to /home/lyvd/bad-snakes/dataset/random-packages/expose-localhost/0.4.2/pypi-sdist-expose-localhost@0.4.2.tar.gz
# hopsfacets 0.0.4
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/hopsfacets to /home/lyvd/bad-snakes/dataset/random-packages/hopsfacets/0.0.4/pypi-bdist_wheel-hopsfacets@0.0.4.whl
# INFO  - Downloaded pkg:pypi/hopsfacets to /home/lyvd/bad-snakes/dataset/random-packages/hopsfacets/0.0.4/pypi-sdist-hopsfacets@0.0.4.tar.gz
# craft 0.2.6
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/craft to /home/lyvd/bad-snakes/dataset/random-packages/craft/0.2.6/pypi-sdist-craft@0.2.6.tar.gz
# plone-rest 2.0.0a5
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/plone-rest to /home/lyvd/bad-snakes/dataset/random-packages/plone-rest/2.0.0a5/pypi-bdist_wheel-plone-rest@2.0.0a5.whl
# INFO  - Downloaded pkg:pypi/plone-rest to /home/lyvd/bad-snakes/dataset/random-packages/plone-rest/2.0.0a5/pypi-sdist-plone-rest@2.0.0a5.tar.gz
# elib 2018.11.22.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/elib to /home/lyvd/bad-snakes/dataset/random-packages/elib/2018.11.22.1/pypi-bdist_wheel-elib@2018.11.22.1.whl
# onnx2torch 1.4.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/onnx2torch to /home/lyvd/bad-snakes/dataset/random-packages/onnx2torch/1.4.1/pypi-bdist_wheel-onnx2torch@1.4.1.whl
# snakeoil 0.9.11
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/snakeoil to /home/lyvd/bad-snakes/dataset/random-packages/snakeoil/0.9.11/pypi-bdist_wheel-snakeoil@0.9.11.whl
# INFO  - Downloaded pkg:pypi/snakeoil to /home/lyvd/bad-snakes/dataset/random-packages/snakeoil/0.9.11/pypi-bdist_wheel-snakeoil@0.9.11.whl
# INFO  - Downloaded pkg:pypi/snakeoil to /home/lyvd/bad-snakes/dataset/random-packages/snakeoil/0.9.11/pypi-sdist-snakeoil@0.9.11.tar.gz
# stackmob-cli 0.1.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/stackmob-cli to /home/lyvd/bad-snakes/dataset/random-packages/stackmob-cli/0.1.1/pypi-sdist-stackmob-cli@0.1.1.tar.gz
# gh-webhook 0.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/gh-webhook to /home/lyvd/bad-snakes/dataset/random-packages/gh-webhook/0.2/pypi-sdist-gh-webhook@0.2.tar.gz
# libafl 0.0.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/libafl to /home/lyvd/bad-snakes/dataset/random-packages/libafl/0.0.2/pypi-sdist-libafl@0.0.2.tar.gz
# formfiller 0.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/formfiller to /home/lyvd/bad-snakes/dataset/random-packages/formfiller/0.3/pypi-sdist-formfiller@0.3.tar.gz
# pait 0.7.8.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/pait to /home/lyvd/bad-snakes/dataset/random-packages/pait/0.7.8.3/pypi-bdist_wheel-pait@0.7.8.3.whl
# INFO  - Downloaded pkg:pypi/pait to /home/lyvd/bad-snakes/dataset/random-packages/pait/0.7.8.3/pypi-sdist-pait@0.7.8.3.tar.gz
# nailpack-flask 0.1.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/nailpack-flask to /home/lyvd/bad-snakes/dataset/random-packages/nailpack-flask/0.1.0/pypi-bdist_wheel-nailpack-flask@0.1.0.whl
# INFO  - Downloaded pkg:pypi/nailpack-flask to /home/lyvd/bad-snakes/dataset/random-packages/nailpack-flask/0.1.0/pypi-sdist-nailpack-flask@0.1.0.tar.gz
# rootwater 0.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/rootwater to /home/lyvd/bad-snakes/dataset/random-packages/rootwater/0.3/pypi-bdist_wheel-rootwater@0.3.whl
# INFO  - Downloaded pkg:pypi/rootwater to /home/lyvd/bad-snakes/dataset/random-packages/rootwater/0.3/pypi-sdist-rootwater@0.3.tar.gz
# idiomxy 0.0.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/idiomxy to /home/lyvd/bad-snakes/dataset/random-packages/idiomxy/0.0.2/pypi-sdist-idiomxy@0.0.2.tar.gz
# django-cadence 0.2.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/django-cadence to /home/lyvd/bad-snakes/dataset/random-packages/django-cadence/0.2.0/pypi-bdist_wheel-django-cadence@0.2.0.whl
# INFO  - Downloaded pkg:pypi/django-cadence to /home/lyvd/bad-snakes/dataset/random-packages/django-cadence/0.2.0/pypi-sdist-django-cadence@0.2.0.tar.gz
# pycodeexport 0.1.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/pycodeexport to /home/lyvd/bad-snakes/dataset/random-packages/pycodeexport/0.1.3/pypi-sdist-pycodeexport@0.1.3.tar.gz
# distributionsbvh 0.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/distributionsbvh to /home/lyvd/bad-snakes/dataset/random-packages/distributionsbvh/0.1/pypi-sdist-distributionsbvh@0.1.tar.gz
# kaiba 1.0.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/kaiba to /home/lyvd/bad-snakes/dataset/random-packages/kaiba/1.0.0/pypi-bdist_wheel-kaiba@1.0.0.whl
# INFO  - Downloaded pkg:pypi/kaiba to /home/lyvd/bad-snakes/dataset/random-packages/kaiba/1.0.0/pypi-sdist-kaiba@1.0.0.tar.gz
# readlif 0.6.5
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/readlif to /home/lyvd/bad-snakes/dataset/random-packages/readlif/0.6.5/pypi-bdist_wheel-readlif@0.6.5.whl
# INFO  - Downloaded pkg:pypi/readlif to /home/lyvd/bad-snakes/dataset/random-packages/readlif/0.6.5/pypi-sdist-readlif@0.6.5.tar.gz
# spiffwarehouse 0.2.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/spiffwarehouse to /home/lyvd/bad-snakes/dataset/random-packages/spiffwarehouse/0.2.0/pypi-sdist-spiffwarehouse@0.2.0.tar.gz
# twinge 0.2.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/twinge to /home/lyvd/bad-snakes/dataset/random-packages/twinge/0.2.3/pypi-sdist-twinge@0.2.3.tar.gz
# ttgmodhello 0.1.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/ttgmodhello to /home/lyvd/bad-snakes/dataset/random-packages/ttgmodhello/0.1.3/pypi-sdist-ttgmodhello@0.1.3.tar.gz
# sorting-asmaa 0.4.6
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/sorting-asmaa to /home/lyvd/bad-snakes/dataset/random-packages/sorting-asmaa/0.4.6/pypi-bdist_wheel-sorting-asmaa@0.4.6.whl
# INFO  - Downloaded pkg:pypi/sorting-asmaa to /home/lyvd/bad-snakes/dataset/random-packages/sorting-asmaa/0.4.6/pypi-sdist-sorting-asmaa@0.4.6.tar.gz
# chillaxd 0.1a2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/chillaxd to /home/lyvd/bad-snakes/dataset/random-packages/chillaxd/0.1a2/pypi-sdist-chillaxd@0.1a2.tar.gz
# python-can 4.0.0.dev2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/python-can to /home/lyvd/bad-snakes/dataset/random-packages/python-can/4.0.0.dev2/pypi-bdist_egg-python-can@4.0.0.dev2.tar.gz
# INFO  - Downloaded pkg:pypi/python-can to /home/lyvd/bad-snakes/dataset/random-packages/python-can/4.0.0.dev2/pypi-sdist-python-can@4.0.0.dev2.tar.gz
# odoo12-addon-l10n-it-website-portal-fatturapa 12.0.1.3.0.99.dev1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/odoo12-addon-l10n-it-website-portal-fatturapa to /home/lyvd/bad-snakes/dataset/random-packages/odoo12-addon-l10n-it-website-portal-fatturapa/12.0.1.3.0.99.dev1/pypi-bdist_wheel-odoo12-addon-l10n-it-website-portal-fatturapa@12.0.1.3.0.99.dev1.whl
# multirelay 0.0.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/multirelay to /home/lyvd/bad-snakes/dataset/random-packages/multirelay/0.0.1/pypi-bdist_wheel-multirelay@0.0.1.whl
# INFO  - Downloaded pkg:pypi/multirelay to /home/lyvd/bad-snakes/dataset/random-packages/multirelay/0.0.1/pypi-sdist-multirelay@0.0.1.tar.gz
# django-appdata 0.3.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/django-appdata to /home/lyvd/bad-snakes/dataset/random-packages/django-appdata/0.3.2/pypi-bdist_wheel-django-appdata@0.3.2.whl
# INFO  - Downloaded pkg:pypi/django-appdata to /home/lyvd/bad-snakes/dataset/random-packages/django-appdata/0.3.2/pypi-sdist-django-appdata@0.3.2.tar.gz
# gsfpy 2.0.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/gsfpy to /home/lyvd/bad-snakes/dataset/random-packages/gsfpy/2.0.0/pypi-bdist_wheel-gsfpy@2.0.0.whl
# INFO  - Downloaded pkg:pypi/gsfpy to /home/lyvd/bad-snakes/dataset/random-packages/gsfpy/2.0.0/pypi-sdist-gsfpy@2.0.0.tar.gz
# chemical-kinetics 1.0.5
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/chemical-kinetics to /home/lyvd/bad-snakes/dataset/random-packages/chemical-kinetics/1.0.5/pypi-bdist_wheel-chemical-kinetics@1.0.5.whl
# INFO  - Downloaded pkg:pypi/chemical-kinetics to /home/lyvd/bad-snakes/dataset/random-packages/chemical-kinetics/1.0.5/pypi-sdist-chemical-kinetics@1.0.5.tar.gz
# hgh-headfirst-test 1.1.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/hgh-headfirst-test to /home/lyvd/bad-snakes/dataset/random-packages/hgh-headfirst-test/1.1.0/pypi-sdist-hgh-headfirst-test@1.1.0.tar.gz
# moz-addon-packager 1.0.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/moz-addon-packager to /home/lyvd/bad-snakes/dataset/random-packages/moz-addon-packager/1.0.1/pypi-sdist-moz-addon-packager@1.0.1.tar.gz
# pure25519 0.0.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/pure25519 to /home/lyvd/bad-snakes/dataset/random-packages/pure25519/0.0.1/pypi-sdist-pure25519@0.0.1.tar.gz
# pyboolet 1.0.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/pyboolet to /home/lyvd/bad-snakes/dataset/random-packages/pyboolet/1.0.1/pypi-sdist-pyboolet@1.0.1.tar.gz
# repcal 1.2.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/repcal to /home/lyvd/bad-snakes/dataset/random-packages/repcal/1.2.1/pypi-bdist_wheel-repcal@1.2.1.whl
# INFO  - Downloaded pkg:pypi/repcal to /home/lyvd/bad-snakes/dataset/random-packages/repcal/1.2.1/pypi-sdist-repcal@1.2.1.tar.gz
# chatpackage 1.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/chatpackage to /home/lyvd/bad-snakes/dataset/random-packages/chatpackage/1.1/pypi-bdist_wheel-chatpackage@1.1.whl
# api-reflector 0.5.10
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/api-reflector to /home/lyvd/bad-snakes/dataset/random-packages/api-reflector/0.5.10/pypi-bdist_wheel-api-reflector@0.5.10.whl
# INFO  - Downloaded pkg:pypi/api-reflector to /home/lyvd/bad-snakes/dataset/random-packages/api-reflector/0.5.10/pypi-sdist-api-reflector@0.5.10.tar.gz
# mopidy-mfe 0.4.9
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/mopidy-mfe to /home/lyvd/bad-snakes/dataset/random-packages/mopidy-mfe/0.4.9/pypi-sdist-mopidy-mfe@0.4.9.tar.gz
# pygments-lexers-graphql 1.0.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/pygments-lexers-graphql to /home/lyvd/bad-snakes/dataset/random-packages/pygments-lexers-graphql/1.0.2/pypi-bdist_wheel-pygments-lexers-graphql@1.0.2.whl
# INFO  - Downloaded pkg:pypi/pygments-lexers-graphql to /home/lyvd/bad-snakes/dataset/random-packages/pygments-lexers-graphql/1.0.2/pypi-sdist-pygments-lexers-graphql@1.0.2.tar.gz
# py-aws-utilities 0.0.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/py-aws-utilities to /home/lyvd/bad-snakes/dataset/random-packages/py-aws-utilities/0.0.3/pypi-bdist_wheel-py-aws-utilities@0.0.3.whl
# INFO  - Downloaded pkg:pypi/py-aws-utilities to /home/lyvd/bad-snakes/dataset/random-packages/py-aws-utilities/0.0.3/pypi-sdist-py-aws-utilities@0.0.3.tar.gz
# alibabacloud-fnf20190315 1.0.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/alibabacloud-fnf20190315 to /home/lyvd/bad-snakes/dataset/random-packages/alibabacloud-fnf20190315/1.0.0/pypi-bdist_wheel-alibabacloud-fnf20190315@1.0.0.whl
# INFO  - Downloaded pkg:pypi/alibabacloud-fnf20190315 to /home/lyvd/bad-snakes/dataset/random-packages/alibabacloud-fnf20190315/1.0.0/pypi-sdist-alibabacloud-fnf20190315@1.0.0.tar.gz
# odoo12-addon-delivery-multi-destination 12.0.1.1.0.99.dev2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/odoo12-addon-delivery-multi-destination to /home/lyvd/bad-snakes/dataset/random-packages/odoo12-addon-delivery-multi-destination/12.0.1.1.0.99.dev2/pypi-bdist_wheel-odoo12-addon-delivery-multi-destination@12.0.1.1.0.99.dev2.whl
# waifu2x-ncnn-vulkan-python 1.0.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/waifu2x-ncnn-vulkan-python to /home/lyvd/bad-snakes/dataset/random-packages/waifu2x-ncnn-vulkan-python/1.0.3/pypi-sdist-waifu2x-ncnn-vulkan-python@1.0.3.tar.gz
# whatsall 2.4
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/whatsall to /home/lyvd/bad-snakes/dataset/random-packages/whatsall/2.4/pypi-sdist-whatsall@2.4.tar.gz
# galaxy-objectstore 21.9.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/galaxy-objectstore to /home/lyvd/bad-snakes/dataset/random-packages/galaxy-objectstore/21.9.0/pypi-bdist_wheel-galaxy-objectstore@21.9.0.whl
# INFO  - Downloaded pkg:pypi/galaxy-objectstore to /home/lyvd/bad-snakes/dataset/random-packages/galaxy-objectstore/21.9.0/pypi-sdist-galaxy-objectstore@21.9.0.tar.gz
# pk-common 0.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/pk-common to /home/lyvd/bad-snakes/dataset/random-packages/pk-common/0.1/pypi-bdist_dumb-pk-common@0.1.tar.gz
# INFO  - Downloaded pkg:pypi/pk-common to /home/lyvd/bad-snakes/dataset/random-packages/pk-common/0.1/pypi-sdist-pk-common@0.1.tar.gz
# unimr-compositeindex 0.1dev
# zicbee 0.9
# taxonerd 1.3.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/taxonerd to /home/lyvd/bad-snakes/dataset/random-packages/taxonerd/1.3.3/pypi-sdist-taxonerd@1.3.3.tar.gz
# pycnc 1.1.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/pycnc to /home/lyvd/bad-snakes/dataset/random-packages/pycnc/1.1.0/pypi-sdist-pycnc@1.1.0.tar.gz
# page-rank-engine 0.2.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/page-rank-engine to /home/lyvd/bad-snakes/dataset/random-packages/page-rank-engine/0.2.0/pypi-bdist_wheel-page-rank-engine@0.2.0.whl
# INFO  - Downloaded pkg:pypi/page-rank-engine to /home/lyvd/bad-snakes/dataset/random-packages/page-rank-engine/0.2.0/pypi-sdist-page-rank-engine@0.2.0.tar.gz
# textgeneratorrandommaximun 0.0.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/textgeneratorrandommaximun to /home/lyvd/bad-snakes/dataset/random-packages/textgeneratorrandommaximun/0.0.1/pypi-bdist_wheel-textgeneratorrandommaximun@0.0.1.whl
# INFO  - Downloaded pkg:pypi/textgeneratorrandommaximun to /home/lyvd/bad-snakes/dataset/random-packages/textgeneratorrandommaximun/0.0.1/pypi-sdist-textgeneratorrandommaximun@0.0.1.tar.gz
# ereuse-rate 0.0.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/ereuse-rate to /home/lyvd/bad-snakes/dataset/random-packages/ereuse-rate/0.0.2/pypi-sdist-ereuse-rate@0.0.2.tar.gz
# simplevue 20210106.6
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/simplevue to /home/lyvd/bad-snakes/dataset/random-packages/simplevue/20210106.6/pypi-sdist-simplevue@20210106.6.tar.gz
# genpurp 0.0.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/genpurp to /home/lyvd/bad-snakes/dataset/random-packages/genpurp/0.0.2/pypi-sdist-genpurp@0.0.2.tar.gz
# deepdrr 1.1.0a4
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/deepdrr to /home/lyvd/bad-snakes/dataset/random-packages/deepdrr/1.1.0a4/pypi-bdist_wheel-deepdrr@1.1.0a4.whl
# INFO  - Downloaded pkg:pypi/deepdrr to /home/lyvd/bad-snakes/dataset/random-packages/deepdrr/1.1.0a4/pypi-sdist-deepdrr@1.1.0a4.tar.gz
# shangshanhui-test 0.0.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/shangshanhui-test to /home/lyvd/bad-snakes/dataset/random-packages/shangshanhui-test/0.0.2/pypi-bdist_wheel-shangshanhui-test@0.0.2.whl
# INFO  - Downloaded pkg:pypi/shangshanhui-test to /home/lyvd/bad-snakes/dataset/random-packages/shangshanhui-test/0.0.2/pypi-sdist-shangshanhui-test@0.0.2.tar.gz
# django-markup-mixin 0.1.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/django-markup-mixin to /home/lyvd/bad-snakes/dataset/random-packages/django-markup-mixin/0.1.0/pypi-sdist-django-markup-mixin@0.1.0.tar.gz
# fiddup 3.0.0
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/fiddup to /home/lyvd/bad-snakes/dataset/random-packages/fiddup/3.0.0/pypi-bdist_wheel-fiddup@3.0.0.whl
# INFO  - Downloaded pkg:pypi/fiddup to /home/lyvd/bad-snakes/dataset/random-packages/fiddup/3.0.0/pypi-sdist-fiddup@3.0.0.tar.gz
# dtsb 0.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/dtsb to /home/lyvd/bad-snakes/dataset/random-packages/dtsb/0.2/pypi-sdist-dtsb@0.2.tar.gz
# tg-distributions 0.3
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/tg-distributions to /home/lyvd/bad-snakes/dataset/random-packages/tg-distributions/0.3/pypi-sdist-tg-distributions@0.3.tar.gz
# sunday-6 0.1
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/sunday-6 to /home/lyvd/bad-snakes/dataset/random-packages/sunday-6/0.1/pypi-bdist_wheel-sunday-6@0.1.whl
# pyinsta 0.2
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/pyinsta to /home/lyvd/bad-snakes/dataset/random-packages/pyinsta/0.2/pypi-sdist-pyinsta@0.2.tar.gz
# ...
# INFO  - Downloaded pkg:pypi/alibabacloud-uis20180821 to /home/lyvd/bad-snakes/dataset/random-packages/alibabacloud-uis20180821/1.0.0
# /pypi-bdist_wheel-alibabacloud-uis20180821@1.0.0.whl
# INFO  - Downloaded pkg:pypi/alibabacloud-uis20180821 to /home/lyvd/bad-snakes/dataset/random-packages/alibabacloud-uis20180821/1.0.0
# /pypi-sdist-alibabacloud-uis20180821@1.0.0.tar.gz
# chaanbot 2.1.0
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/chaanbot to /home/lyvd/bad-snakes/dataset/random-packages/chaanbot/2.1.0
# /pypi-bdist_wheel-chaanbot@2.1.0.whl
# INFO  - Downloaded pkg:pypi/chaanbot to /home/lyvd/bad-snakes/dataset/random-packages/chaanbot/2.1.0
# /pypi-sdist-chaanbot@2.1.0.tar.gz
# bayesfit-ap 0.1.1
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/bayesfit-ap to /home/lyvd/bad-snakes/dataset/random-packages/bayesfit-ap/0.1.1
# /pypi-sdist-bayesfit-ap@0.1.1.tar.gz
# airflow-ray-executor 0.0.1
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/airflow-ray-executor to /home/lyvd/bad-snakes/dataset/random-packages/airflow-ray-executor/0.0.1
# /pypi-bdist_wheel-airflow-ray-executor@0.0.1.whl
# INFO  - Downloaded pkg:pypi/airflow-ray-executor to /home/lyvd/bad-snakes/dataset/random-packages/airflow-ray-executor/0.0.1
# /pypi-sdist-airflow-ray-executor@0.0.1.tar.gz
# uhammer 0.4.0
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/uhammer to /home/lyvd/bad-snakes/dataset/random-packages/uhammer/0.4.0
# /pypi-sdist-uhammer@0.4.0.tar.gz
# convey 1.3.15
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/convey to /home/lyvd/bad-snakes/dataset/random-packages/convey/1.3.15
# /pypi-sdist-convey@1.3.15.tar.gz
# peaksvalleys 1.2.2
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/peaksvalleys to /home/lyvd/bad-snakes/dataset/random-packages/peaksvalleys/1.2.2
# /pypi-bdist_wheel-peaksvalleys@1.2.2.whl
# INFO  - Downloaded pkg:pypi/peaksvalleys to /home/lyvd/bad-snakes/dataset/random-packages/peaksvalleys/1.2.2
# /pypi-sdist-peaksvalleys@1.2.2.tar.gz
# lcba 0.2.6
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/lcba to /home/lyvd/bad-snakes/dataset/random-packages/lcba/0.2.6
# /pypi-sdist-lcba@0.2.6.tar.gz
# outremove-manav1811kumar 0.0.5
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/outremove-manav1811kumar to /home/lyvd/bad-snakes/dataset/random-packages/outremove-manav1811kumar/0.0.5
# /pypi-bdist_wheel-outremove-manav1811kumar@0.0.5.whl
# INFO  - Downloaded pkg:pypi/outremove-manav1811kumar to /home/lyvd/bad-snakes/dataset/random-packages/outremove-manav1811kumar/0.0.5
# /pypi-sdist-outremove-manav1811kumar@0.0.5.tar.gz
# mllego 0.32
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/mllego to /home/lyvd/bad-snakes/dataset/random-packages/mllego/0.32
# /pypi-sdist-mllego@0.32.tar.gz
# primme 3.2.1
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/primme to /home/lyvd/bad-snakes/dataset/random-packages/primme/3.2.1
# /pypi-sdist-primme@3.2.1.tar.gz
# esiosdata 0.6.10
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/esiosdata to /home/lyvd/bad-snakes/dataset/random-packages/esiosdata/0.6.10
# /pypi-bdist_wheel-esiosdata@0.6.10.whl
# INFO  - Downloaded pkg:pypi/esiosdata to /home/lyvd/bad-snakes/dataset/random-packages/esiosdata/0.6.10
# /pypi-sdist-esiosdata@0.6.10.tar.gz
# nmtf 1.0.83
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/nmtf to /home/lyvd/bad-snakes/dataset/random-packages/nmtf/1.0.83
# /pypi-bdist_egg-nmtf@1.0.83.tar.gz
# INFO  - Downloaded pkg:pypi/nmtf to /home/lyvd/bad-snakes/dataset/random-packages/nmtf/1.0.83
# /pypi-sdist-nmtf@1.0.83.tar.gz
# spwk-cartesius 0.1.0
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/spwk-cartesius to /home/lyvd/bad-snakes/dataset/random-packages/spwk-cartesius/0.1.0
# /pypi-bdist_wheel-spwk-cartesius@0.1.0.whl
# INFO  - Downloaded pkg:pypi/spwk-cartesius to /home/lyvd/bad-snakes/dataset/random-packages/spwk-cartesius/0.1.0
# /pypi-sdist-spwk-cartesius@0.1.0.tar.gz
# awesome-slugify 1.6.5
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/awesome-slugify to /home/lyvd/bad-snakes/dataset/random-packages/awesome-slugify/1.6.5
# /pypi-sdist-awesome-slugify@1.6.5.tar.gz
# django-triflesoft-localization 0.7.1702191535
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/django-triflesoft-localization to /home/lyvd/bad-snakes/dataset/random-packages/django-triflesoft-localization/0.7.1702191535
# /pypi-bdist_wheel-django-triflesoft-localization@0.7.1702191535.whl
# pyassemble 1.0.0
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/pyassemble to /home/lyvd/bad-snakes/dataset/random-packages/pyassemble/1.0.0
# /pypi-sdist-pyassemble@1.0.0.tar.gz
# mentalpoker 0.5.0
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/mentalpoker to /home/lyvd/bad-snakes/dataset/random-packages/mentalpoker/0.5.0
# /pypi-bdist_wheel-mentalpoker@0.5.0.whl
# INFO  - Downloaded pkg:pypi/mentalpoker to /home/lyvd/bad-snakes/dataset/random-packages/mentalpoker/0.5.0
# /pypi-sdist-mentalpoker@0.5.0.tar.gz
# ivozzo-pyboilerplate 1.0.0
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/ivozzo-pyboilerplate to /home/lyvd/bad-snakes/dataset/random-packages/ivozzo-pyboilerplate/1.0.0
# /pypi-bdist_wheel-ivozzo-pyboilerplate@1.0.0.whl
# INFO  - Downloaded pkg:pypi/ivozzo-pyboilerplate to /home/lyvd/bad-snakes/dataset/random-packages/ivozzo-pyboilerplate/1.0.0
# /pypi-sdist-ivozzo-pyboilerplate@1.0.0.tar.gz
# torcp 0.46
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/torcp to /home/lyvd/bad-snakes/dataset/random-packages/torcp/0.46
# /pypi-sdist-torcp@0.46.tar.gz
# iloveruby-zh 2020.9.21.0
#
#
#    ____   _____ _____    _____           _            _
#   / __ \ / ____/ ____|  / ____|         | |          | |
#  | |  | | (___| (___   | |  __  __ _  __| | __ _  ___| |_
#  | |  | |\___ \\___ \  | | |_ |/ _` |/ _` |/ _` |/ _ \ __|
#  | |__| |____) |___) | | |__| | (_| | (_| | (_| |  __/ |_
#   \____/|_____/_____/   \_____|\__,_|\__,_|\__, |\___|\__|
#                                             __/ |
#                                            |___/
# OSS Gadget - oss-download 0.1.338+9f1c90696a - github.com/Microsoft/OSSGadget
# INFO  - Downloaded pkg:pypi/iloveruby-zh to /home/lyvd/bad-snakes/dataset/random-packages/iloveruby-zh/2020.9.21.0
# /pypi-bdist_wheel-iloveruby-zh@2020.9.21.0.whl
# INFO  - Downloaded pkg:pypi/iloveruby-zh to /home/lyvd/bad-snakes/dataset/random-packages/iloveruby-zh/2020.9.21.0
# /pypi-sdist-iloveruby-zh@2020.9.21.0.tar.gz

# %%
/home/lyvd/bad-snakes/dataset/popular-packages/vtk/9.2.0rc2/pypi-bdist_wheel-vtk@9.2.0rc2.whl'
